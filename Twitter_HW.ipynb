# %%
# Dependencies
import numpy as np
import pandas as pd
import tweepy
import time
import json
import matplotlib.pyplot as plt
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = "r4b58sAz2lqEQZj3DpMkc0ibi"
consumer_secret = "kHH72T9XrpzGHJAgdVRZAlaRLEeDPm0AujM2pdNQpU4uhVxgUJ"
access_token = "975021712332017665-beqYO52oVSm94MsENtMoMY0XrJc9x1F"
access_token_secret = "5a2BWlPfRKxONfShepLlj2farPcNnkSdH9Kz9ODCR45mu"

# %%
# Twitter Credentials
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term
target_terms = ["@CNN", "@BBC", "@CBS","@FOX", "NYT"]
min_tweets = 100
max_tweets = 100
max_followers = 100
max_following = 100
lang = "en"

# %%
# Add List to hold sentiment
for target in target_terms:
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

# %%
# Grab 100 tweets
public_tweets = api.search(target, count=100, result_type="recent")
print(public_tweets)
# Out:
# {'statuses': [{'created_at': 'Sun Mar 25 22:05:21 +0000 2018', 'id': 978030101999779841, 'id_str': '978030101999779841', 'text': '@nytimes So refreshing to hear NYT comment on something important like how automation will kill jobs, mental health… https://t.co/UczjbqS3Sc', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'nytimes', 'name': 'The New York Times', 'id': 807095, 'id_str': '807095', 'indices': [0, 8]}], 'urls': [{'url': 'https://t.co/UczjbqS3Sc', 'expanded_url': 'https://twitter.com/i/web/status/978030101999779841', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [117, 140]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': 978028830295281665, 'in_reply_to_status_id_str': '978028830295281665', 'in_reply_to_user_id': 807095, 'in_reply_to_user_id_str': '807095', 'in_reply_to_screen_name': 'nytimes', 'user': {'id': 1596013357, 'id_str': '1596013357', 'name': 'Christian Consvr. Co', 'screen_name': 'TonyPumz', 'location': 'N', 'description': 'VETERAN', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 33, 'friends_count': 63, 'listed_count': 0, 'created_at': 'Mon Jul 15 14:36:00 +0000 2013', 'favourites_count': 64, 'utc_offset': -14400, 'time_zone': 'Eastern Time (US & Canada)', 'geo_enabled': False, 'verified': False, 'statuses_count': 187, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '080808', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/444549368540954624/in3KpCJC.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/444549368540954624/in3KpCJC.jpeg', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/820396057624449025/_fFRb4iC_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/820396057624449025/_fFRb4iC_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1596013357/1373917128', 'profile_link_color': '7FDBB6', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, {'created_at': 'Sun Mar 25 22:05:19 +0000 2018', 'id': 978030090608107520, 'id_str': '978030090608107520', 'text': 'RT @justin_halpern: Here’s what’ll happen after Trump’s dick pic comes out:\n\n1. Charlie Kirk argues small dicks are actually the best kind…', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'justin_halpern', 'name': 'Justin Halpern', 'id': 130339829, 'id_str': '130339829', 'indices': [3, 18]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 46299602, 'id_str': '46299602', 'name': 'suziQZ', 'screen_name': 'Bannington', 'location': 'Red Sox Nation', 'description': '✨"can\'t talk to you without talking to me"💫', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 407, 'friends_count': 990, 'listed_count': 1, 'created_at': 'Thu Jun 11 03:07:06 +0000 2009', 'favourites_count': 14708, 'utc_offset': -14400, 'time_zone':  ...

# %%
# Loop through all tweets
for tweet in public_tweets["statuses"]:

#  Run Vader Analysis on each tweet
    compound = analyzer.polarity_scores(tweet["text"])["compound"]
    pos = analyzer.polarity_scores(tweet["text"])["pos"]
    neu = analyzer.polarity_scores(tweet["text"])["neu"]
    neg = analyzer.polarity_scores(tweet["text"])["neg"]

# %%
#  Add each value to the appropriate array
compound_list.append(compound)
positive_list.append(pos)
negative_list.append(neg)
neutral_list.append(neu)

# %%
# Store the Average Sentiments
sentiment = {"Compound": np.mean(compound_list),
             "Positive": np.mean(positive_list),
             "Negative": np.mean(negative_list),
             "Neutral": np.mean(neutral_list),}
# Print the Sentiments
print(sentiment)
# Out:
# {'Compound': 0.0, 'Positive': 0.0, 'Negative': 0.0, 'Neutral': 1.0}

# %%
plt.scatter([Compound],[Neutral],
            edgecolor="black", 
            linewidths=1, marker="o",
            alpha=0.8, label="Sentiment Analysis of Media Tweets")

plt.title("Sentiment Analysis of Media Tweets")
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid(True)
plt.xlim([-2.5, 202])
plt.ylim([-2.5, 110000])

plt.savefig("Sentiment_Analysis.png")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-d723c45a4b19> in <module>()
# ----> 1 plt.scatter([Compound],[Neutral],
#       2             edgecolor="black",
#       3             linewidths=1, marker="o",
#       4             alpha=0.8, label="Sentiment Analysis of Media Tweets")
#       5
#
# NameError: name 'Compound' is not defined
